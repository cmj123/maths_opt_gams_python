# %% [markdown]
# ## LP - Ortools

# %%
from ortools.linear_solver import pywraplp

# %%
solver = pywraplp.Solver.CreateSolver('GLOP')

# %%
x = solver.NumVar(0,10, 'x')
y = solver.NumVar(0,10, 'y')

# %%
solver.Add(-x+2*y<=8)
solver.Add(2*x+y<=14)
solver.Add(2*x-y<=10)
# Out:
# <ortools.linear_solver.pywraplp.Constraint; proxy of <Swig Object of type 'operations_research::MPConstraint *' at 0x7fb850e43c60> >

# %%
solver.Maximize(x+y)

# %%
results = solver.Solve()

# %%
if results == pywraplp.Solver.OPTIMAL:
    print('Optimal Found')
print('x: ', x.solution_value())
print('y: ', y.solution_value())
# Out:
# Optimal Found
# x:  4.0
# y:  6.0

# %%
# visualise the result
from numpy import arange
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# %%
# Objective function
def objective(x,y):
    return x+y

# Define range for input
r_min, r_max = 3.0, 7.0

# Sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)

# Create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)

# compute targets
results = objective(x,y)

# create a surface plot with the jet color scheme
figure = pyplot.figure(figsize=(15,10))
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')

# Show the plot
pyplot.show()

# %%
results
# Out:
# array([[ 6. ,  6.1,  6.2, ...,  9.7,  9.8,  9.9],
#        [ 6.1,  6.2,  6.3, ...,  9.8,  9.9, 10. ],
#        [ 6.2,  6.3,  6.4, ...,  9.9, 10. , 10.1],
#        ...,
#        [ 9.7,  9.8,  9.9, ..., 13.4, 13.5, 13.6],
#        [ 9.8,  9.9, 10. , ..., 13.5, 13.6, 13.7],
#        [ 9.9, 10. , 10.1, ..., 13.6, 13.7, 13.8]])
